# %%
import os
import requests
import urllib
import json
from datetime import date, datetime
import time
import pandas as pd
from collections import defaultdict
import sqlalchemy
from build_db import connect, build_matches, append_matches,\
    append_player_matches, build_player_matches, build_heroes, build_hero_ranking,\
    append_hero_ranking, build_mmr_estimates, append_mmr_estimates

# %% [markdown]
# #  Match Data
#
# Lets go grab the match id of a recent match off dotabuff:
# 3440629665

# %%
match_url = 'https://api.opendota.com/api/matches/{match_id}'
r = requests.get(match_url.format(match_id=3440629665))
content = json.loads(r.content)

# %% [markdown]
# # Writing our own queries
# OpenDotA implements OpenAPI standard, which allows us to submit our own SQL queries to their postgreSQL database.
# Let's start by seeing what tables we can query.

# %%
def explorer_request(request):
    '''
    Parameters: request(string)
    Returns: rows(list of outputs)
    '''
    explorer_url = 'https://api.opendota.com/api/explorer?sql='
    request_url = urllib.quote(request)
    r = requests.get(explorer_url + request_url)
    rows = json.loads(r.content)['rows']
    return rows

# %% [markdown]
# ** Get Schema **

# %%
tables_query = '''
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema='public'
    AND table_type='BASE TABLE';
'''


tables = [row['table_name'] for row in explorer_request(tables_query)]
tables
# Out:
# [u'matches',
#  u'team_rating',
#  u'hero_ranking',
#  u'mmr_estimates',
#  u'player_matches',
#  u'heroes',
#  u'public_matches',
#  u'queue',
#  u'solo_competitive_rank',
#  u'competitive_rank',
#  u'public_player_matches',
#  u'leagues',
#  u'items',
#  u'team_match',
#  u'match_patch',
#  u'picks_bans',
#  u'teams',
#  u'notable_players',
#  u'match_logs']

# %% [markdown]
# How many matches can a single query return?

# %%
public_player_match_query = urllib.quote('''
SELECT * FROM public_player_matches LIMIT 1000
''')
r = requests.get(explorer_url + public_player_match_query)
public_matches_100 = json.loads(r.content)

len(public_matches_100['rows'])
# Out:
# 1000

# %% [markdown]
# A lot apparently. With a rate limit of 3/s this should be more than adequate. Let's see if we can write a query to return CM matches only. CM is game mode 4 according to dota 2 wiki, though we can confirm that later.

# %% [markdown]
# ### Querying individual match data
# Fields of interest:
# - duration: int, length of the match in seconds
# - game_mode: int 0 for none, 1 for AP, 2 for CM
# - match_id
# - picks_bans: list of pick/ban dictionaries { 'is_pick': boolean, 'hero_id': int, 'order': int, 'team': int }
# - radiant_win: boolean
# - start_time: int, convert to date using date.fromtimestamp(ord)
# - match_seq_num: number indicating order of matches

# %%
matches_query = urllib.quote('''
SELECT * FROM matches LIMIT 1
''')
r = requests.get(explorer_url + matches_query)
matches = json.loads(r.content)

matches['rows']
# Out:
# [{u'barracks_status_dire': 63,
#   u'barracks_status_radiant': 0,
#   u'chat': [{u'key': u'gg',
#     u'time': 4016,
#     u'type': u'chat',
#     u'unit': u'iG.Faith'},
#    {u'key': u'gg',
#     u'time': 4019,
#     u'type': u'chat',
#     u'unit': u'\u8001\u7537\u5b69'},
#    {u'key': u'gg',
#     u'time': 4020,
#     u'type': u'chat',
#     u'unit': u'\u53ef\u8fbe\u9e2d'}],
#   u'cluster': 225,
#   u'cosmetics': {},
#   u'dire_captain': 98887913,
#   u'dire_score': 0,
#   u'dire_team_complete': 1,
#   u'dire_team_id': 1375614,
#   u'dire_team_name': None,
#   u'duration': 3224,
#   u'engine': 0,
#   u'first_blood_time': 65,
#   u'game_mode': 2,
#   u'human_players': 10,
#   u'leagueid': 1284,
#   u'lobby_type': 1,
#   u'match_id': 728669374,
#   u'match_seq_num': 656191098,
#   u'negative_votes': 10,
#   u'objectives': [{u'key': 0,
#     u'slot': 8,
#     u'time': 867,
#     u'type': u'CHAT_MESSAGE_FIRSTBLOOD'},
#    {u'slot': 6,
#     u'team': 100,
#     u'time': 1291,
#     u'type': u'CHAT_MESSAGE_TOWER_DENY'},
#    {u'slot': 9,
#     u'team': 3,
#     u'time': 1567,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 8,
#     u'team': 3,
#     u'time': 1683,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 0,
#     u'team': 2,
#     u'time': 1688,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 6,
#     u'team': 100,
#     u'time': 1758,
#     u'type': u'CHAT_MESSAGE_TOWER_DENY'},
#    {u'slot': 6,
#     u'team': 3,
#     u'time': 1924,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'team': 2, u'time': 2393, u'type': u'CHAT_MESSAGE_ROSHAN_KILL'},
#    {u'slot': 1, u'time': 2393, u'type': u'CHAT_MESSAGE_AEGIS'},
#    {u'slot': -1,
#     u'team': 2,
#     u'time': 2949,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'team': 3, u'time': 3099, u'type': u'CHAT_MESSAGE_ROSHAN_KILL'},
#    {u'slot': 6, u'time': 3099, u'type': u'CHAT_MESSAGE_AEGIS'},
#    {u'slot': 8,
#     u'team': 3,
#     u'time': 3141,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 9,
#     u'team': 3,
#     u'time': 3291,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 6,
#     u'team': 3,
#     u'time': 3404,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'slot': 8,
#     u'team': 3,
#     u'time': 3606,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'key': u'1024', u'time': 3618, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'},
#    {u'key': u'2048', u'time': 3622, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'},
#    {u'team': 3, u'time': 3816, u'type': u'CHAT_MESSAGE_ROSHAN_KILL'},
#    {u'slot': 6, u'time': 3818, u'type': u'CHAT_MESSAGE_AEGIS'},
#    {u'slot': 9,
#     u'team': 3,
#     u'time': 3905,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'key': u'64', u'time': 3923, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'},
#    {u'slot': 5,
#     u'team': 3,
#     u'time': 4009,
#     u'type': u'CHAT_MESSAGE_TOWER_KILL'},
#    {u'key': u'512', u'time': 4016, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'},
#    {u'key': u'128', u'time': 4018, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'},
#    {u'key': u'256', u'time': 4019, u'type': u'CHAT_MESSAGE_BARRACKS_KILL'}],
#   u'picks_bans': [{u'hero_id': 89, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 77, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 69, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 58, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 65, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 9, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 103, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 78, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 29, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 53, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 68, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 27, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 47, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 86, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 41, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 67, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'positive_votes': 74,
#   u'radiant_captain': 82327674,
#   u'radiant_gold_adv': [],
#   u'radiant_score': 0,
#   u'radiant_team_complete': 1,
#   u'radiant_team_id': 5,
#   u'radiant_team_name': None,
#   u'radiant_win': False,
#   u'radiant_xp_adv': [],
#   u'start_time': 1403182330,
#   u'teamfights': [],
#   u'tower_status_dire': 1846,
#   u'tower_status_radiant': 1536,
#   u'version': 20}]

# %% [markdown]
# ### Querying CM matches
# In order to build our query properly, we want to grab all the public matches between the dates
# 2017-05-15
# and
# 2017-09-18 where game_mode = 2.

# %%
def parse_date(date):
    return int(time.mktime(datetime.strptime(date, '%Y-%m-%d').timetuple()))
start = parse_date('2016-12-12')
end = parse_date('2017-09-18')

# %%
cm_query = '''
SELECT match_id, duration,
picks_bans, radiant_win,
match_seq_num
FROM matches 
WHERE start_time BETWEEN {start} AND {end}
ORDER BY match_seq_num ASC
LIMIT 20;
'''.format(start=start, end=end)
explorer_request(cm_query)
# Out:
# [{u'duration': 1969,
#   u'match_id': 3180507665,
#   u'match_seq_num': 2778110720,
#   u'picks_bans': [{u'hero_id': 114,
#     u'is_pick': False,
#     u'order': 0,
#     u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 88, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 104, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 32, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 14, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 106, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 54, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 76, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 8, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 55, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 74, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 37, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 57, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 65, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 70, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 63, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 109, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 10, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': True},
#  {u'duration': 1356,
#   u'match_id': 3180707501,
#   u'match_seq_num': 2778275515,
#   u'picks_bans': [{u'hero_id': 57, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 83, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 88, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 32, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 102, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 55, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 114, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 70, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 111, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 30, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 59, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 25, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 109, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 49, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 95, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 34, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': True},
#  {u'duration': 1705,
#   u'match_id': 3180807310,
#   u'match_seq_num': 2778377937,
#   u'picks_bans': [{u'hero_id': 32, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 57, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 83, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 114, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 109, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 104, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 8, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 25, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 88, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 30, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 55, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 13, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 28, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 16, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 107, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 51, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2338,
#   u'match_id': 3180828452,
#   u'match_seq_num': 2778416570,
#   u'picks_bans': [{u'hero_id': 25, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 88, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 32, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 37, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 99, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 74, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 102, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 2, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 107, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 104, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 55, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 11, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 28, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 76, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 51, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 15, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2570,
#   u'match_id': 3180953074,
#   u'match_seq_num': 2778549215,
#   u'picks_bans': [{u'hero_id': 99, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 55, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 25, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 5, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 83, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 11, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 104, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 107, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 51, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 102, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 93, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 14, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 57, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 4, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 97, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 18, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': True},
#  {u'duration': 3292,
#   u'match_id': 3181311283,
#   u'match_seq_num': 2778923803,
#   u'picks_bans': [{u'hero_id': 97, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 114, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 104, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 82, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 83, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 28, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 110, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 2, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 95, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 57, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 54, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 107, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 70, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 33, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 46, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 11, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False},
#  {u'duration': 2231,
#   u'match_id': 3181382296,
#   u'match_seq_num': 2778936924,
#   u'picks_bans': [{u'hero_id': 28, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 102, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 2, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 97, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 52, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 88, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 16, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 67, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 54, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 95, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 83, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 23, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 34, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 46, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 43, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 25, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': True},
#  {u'duration': 1634,
#   u'match_id': 3181413350,
#   u'match_seq_num': 2778940566,
#   u'picks_bans': [{u'hero_id': 97, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 114, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 55, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 83, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 64, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 96, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 104, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 76, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 1, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 57, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 95, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 112, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 110, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 63, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 82, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 34, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 106, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 8, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': True},
#  {u'duration': 2492,
#   u'match_id': 3181490967,
#   u'match_seq_num': 2779061980,
#   u'picks_bans': [{u'hero_id': 91, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 83, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 37, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 102, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 97, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 51, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 11, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 8, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 84, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 109, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 46, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 75, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 57, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 32, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 44, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 55, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 98, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 1343,
#   u'match_id': 3181614447,
#   u'match_seq_num': 2779164505,
#   u'picks_bans': [{u'hero_id': 53, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 5, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 82, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 83, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 37, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 86, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 104, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 97, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 95, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 76, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 11, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 28, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 114, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 70, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 25, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 74, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 56, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 34, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False},
#  {u'duration': 2616,
#   u'match_id': 3181698424,
#   u'match_seq_num': 2779248028,
#   u'picks_bans': [{u'hero_id': 37, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 83, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 10, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 104, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 97, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 51, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 90, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 8, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 45, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 11, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 33, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 109, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 50, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 76, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 60, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 75, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 16, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 35, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': True},
#  {u'duration': 2724,
#   u'match_id': 3181880636,
#   u'match_seq_num': 2779401121,
#   u'picks_bans': [{u'hero_id': 83, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 90, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 37, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 5, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 109, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 34, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 102, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 35, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 45, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 110, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 99, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 65, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 87, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 76, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 22, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 52, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2959,
#   u'match_id': 3182170543,
#   u'match_seq_num': 2779643823,
#   u'picks_bans': [{u'hero_id': 11, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 97, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 90, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 83, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 51, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 102, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 87, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 7, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 28, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 71, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 46, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 98, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 86, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 1, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 89, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 80, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 109, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False},
#  {u'duration': 1336,
#   u'match_id': 3182329794,
#   u'match_seq_num': 2779741716,
#   u'picks_bans': [{u'hero_id': 55, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 11, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 83, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 102, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 37, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 90, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 99, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 109, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 70, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 60, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 77, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 95, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 104, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 17, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 76, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 39, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2292,
#   u'match_id': 3182408768,
#   u'match_seq_num': 2779839056,
#   u'picks_bans': [{u'hero_id': 97, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 90, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 51, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 83, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 55, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 5, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 69, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 71, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 37, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 8, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 80, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 106, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 11, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 62, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 110, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 54, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 70, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 44, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 95, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False},
#  {u'duration': 1470,
#   u'match_id': 3182758985,
#   u'match_seq_num': 2780134224,
#   u'picks_bans': [{u'hero_id': 97, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 96, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 88, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 79, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 112, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 84, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 41, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 48, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 109, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 29, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 54, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 47, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 75, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 17, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': True},
#  {u'duration': 2130,
#   u'match_id': 3182809929,
#   u'match_seq_num': 2780200551,
#   u'picks_bans': [{u'hero_id': 29, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 96, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 73, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 16, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 84, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 26, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 5, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 54, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 46, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 88, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 80, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 78, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 55, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 93, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 34, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 76, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 13, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 62, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False},
#  {u'duration': 3115,
#   u'match_id': 3182823507,
#   u'match_seq_num': 2780243100,
#   u'picks_bans': [{u'hero_id': 85, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 8, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 27, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 54, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 64, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 31, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 30, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 35, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 96, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 93, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 43, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 6, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 104, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 92, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 77, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 47, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 46, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 34, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 25, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2047,
#   u'match_id': 3182953925,
#   u'match_seq_num': 2780342183,
#   u'picks_bans': [{u'hero_id': 102,
#     u'is_pick': False,
#     u'order': 0,
#     u'team': 1},
#    {u'hero_id': 85, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 110, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 27, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 71, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 86, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 84, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 96, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 20, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 54, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 2, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 8, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 35, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 47, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 107, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 109, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 97, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 82, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 16, u'is_pick': True, u'order': 19, u'team': 0}],
#   u'radiant_win': False},
#  {u'duration': 2416,
#   u'match_id': 3183066907,
#   u'match_seq_num': 2780445030,
#   u'picks_bans': [{u'hero_id': 85, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 93, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 82, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 7, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 30, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 102, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 83, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 104, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 109, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 70, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 54, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 36, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 96, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 46, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 35, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 8, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 67, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 1, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 44, u'is_pick': True, u'order': 19, u'team': 1}],
#   u'radiant_win': False}]

# %% [markdown]
# ### Player Data
# Later on down the line we may want to add player data to our analysis.

# %% [markdown]
# ###### player_matches
# Useful fields in player_matches: account_id (to join with mmr_estimates), match_id (to join with matches), hero_id

# %%
player_request = '''
SELECT * FROM player_matches LIMIT 1;
'''
explorer_request(player_request)
# Out:
# [{u'ability_upgrades_arr': [5023,
#    5024,
#    5023,
#    5025,
#    5023,
#    5026,
#    5023,
#    5025,
#    5025,
#    5025,
#    5026],
#   u'ability_uses': {u'earthshaker_echo_slam': 2,
#    u'earthshaker_enchant_totem': 32,
#    u'earthshaker_fissure': 39},
#   u'account_id': 112250781,
#   u'actions': {u'1': 5965,
#    u'10': 348,
#    u'11': 11,
#    u'15': 4,
#    u'16': 21,
#    u'19': 16,
#    u'2': 118,
#    u'3': 5,
#    u'33': 348,
#    u'4': 474,
#    u'5': 74,
#    u'6': 4,
#    u'7': 4,
#    u'8': 86},
#   u'additional_units': None,
#   u'assists': 7,
#   u'backpack_0': 0,
#   u'backpack_1': 0,
#   u'backpack_2': 0,
#   u'buyback_log': [],
#   u'camps_stacked': None,
#   u'creeps_stacked': None,
#   u'damage': {u'illusion_npc_dota_hero_templar_assassin': 634,
#    u'npc_dota_badguys_siege': 482,
#    u'npc_dota_creep_badguys_melee': 13039,
#    u'npc_dota_creep_badguys_melee_upgraded': 1068,
#    u'npc_dota_creep_badguys_ranged': 6019,
#    u'npc_dota_dark_troll_warlord_skeleton_warrior': 895,
#    u'npc_dota_hero_batrider': 955,
#    u'npc_dota_hero_earth_spirit': 479,
#    u'npc_dota_hero_gyrocopter': 1841,
#    u'npc_dota_hero_oracle': 761,
#    u'npc_dota_hero_templar_assassin': 729,
#    u'npc_dota_neutral_centaur_khan': 318,
#    u'npc_dota_neutral_dark_troll': 1392,
#    u'npc_dota_neutral_dark_troll_warlord': 1392,
#    u'npc_dota_neutral_gnoll_assassin': 1056,
#    u'npc_dota_neutral_polar_furbolg_champion': 765,
#    u'npc_dota_neutral_polar_furbolg_ursa_warrior': 1034,
#    u'npc_dota_neutral_satyr_hellcaller': 1954,
#    u'npc_dota_neutral_satyr_soulstealer': 1299,
#    u'npc_dota_neutral_satyr_trickster': 885,
#    u'npc_dota_sentry_wards': 156},
#   u'damage_inflictor': {u'earthshaker_aftershock': 266,
#    u'earthshaker_echo_slam': 816,
#    u'earthshaker_fissure': 3274,
#    u'null': 409},
#   u'damage_inflictor_received': {u'batrider_firefly': 972,
#    u'batrider_flamebreak': 309,
#    u'batrider_sticky_napalm': 215,
#    u'earth_spirit_boulder_smash': 230,
#    u'earth_spirit_geomagnetic_grip': 269,
#    u'earth_spirit_magnetize': 228,
#    u'earth_spirit_rolling_boulder': 76,
#    u'gyrocopter_call_down': 344,
#    u'gyrocopter_rocket_barrage': 1171,
#    u'null': 2363,
#    u'oracle_fortunes_end': 69,
#    u'oracle_purifying_flames': 553,
#    u'templar_assassin_meld': 283,
#    u'urn_of_shadows': 57},
#   u'damage_taken': {u'dota_unknown': 2,
#    u'npc_dota_badguys_tower1_mid': 833,
#    u'npc_dota_creep_badguys_melee': 592,
#    u'npc_dota_creep_badguys_ranged': 353,
#    u'npc_dota_dark_troll_warlord_skeleton_warrior': 67,
#    u'npc_dota_hero_batrider': 1556,
#    u'npc_dota_hero_earth_spirit': 902,
#    u'npc_dota_hero_gyrocopter': 2514,
#    u'npc_dota_hero_oracle': 670,
#    u'npc_dota_hero_templar_assassin': 1497,
#    u'npc_dota_neutral_dark_troll': 56,
#    u'npc_dota_neutral_dark_troll_warlord': 159,
#    u'npc_dota_neutral_gnoll_assassin': 209,
#    u'npc_dota_neutral_polar_furbolg_champion': 93,
#    u'npc_dota_neutral_polar_furbolg_ursa_warrior': 156,
#    u'npc_dota_neutral_satyr_hellcaller': 79,
#    u'npc_dota_neutral_satyr_soulstealer': 43,
#    u'npc_dota_neutral_satyr_trickster': 7},
#   u'deaths': 5,
#   u'denies': 0,
#   u'firstblood_claimed': None,
#   u'gold': 1033,
#   u'gold_per_min': 256,
#   u'gold_reasons': {u'0': 788,
#    u'1': -1135,
#    u'11': 600,
#    u'12': 1015,
#    u'13': 2972,
#    u'5': 162},
#   u'gold_spent': 6865,
#   u'gold_t': [0,
#    140,
#    280,
#    416,
#    516,
#    943,
#    1044,
#    1299,
#    1583,
#    1920,
#    2202,
#    2426,
#    2944,
#    3044,
#    3365,
#    3910,
#    4220,
#    4398,
#    4614,
#    4842,
#    5168,
#    5742,
#    5896,
#    6170,
#    6313,
#    6512,
#    7115,
#    7215,
#    7315,
#    7575,
#    7751,
#    7851,
#    8046,
#    8046],
#   u'hero_damage': 3376,
#   u'hero_healing': 0,
#   u'hero_hits': {u'earthshaker_aftershock': 4,
#    u'earthshaker_echo_slam': 18,
#    u'earthshaker_fissure': 21,
#    u'null': 7},
#   u'hero_id': 7,
#   u'is_roaming': False,
#   u'item_0': 1,
#   u'item_1': 36,
#   u'item_2': 102,
#   u'item_3': 188,
#   u'item_4': 46,
#   u'item_5': 180,
#   u'item_uses': {u'arcane_boots': 19,
#    u'blink': 17,
#    u'clarity': 2,
#    u'force_staff': 2,
#    u'magic_wand': 1,
#    u'tango': 4,
#    u'tpscroll': 6},
#   u'kill_streaks': {},
#   u'killed': {u'npc_dota_badguys_siege': 2,
#    u'npc_dota_creep_badguys_melee': 34,
#    u'npc_dota_creep_badguys_melee_upgraded': 1,
#    u'npc_dota_creep_badguys_ranged': 16,
#    u'npc_dota_dark_troll_warlord_skeleton_warrior': 2,
#    u'npc_dota_hero_batrider': 1,
#    u'npc_dota_neutral_centaur_khan': 1,
#    u'npc_dota_neutral_dark_troll': 2,
#    u'npc_dota_neutral_dark_troll_warlord': 1,
#    u'npc_dota_neutral_gnoll_assassin': 3,
#    u'npc_dota_neutral_polar_furbolg_champion': 1,
#    u'npc_dota_neutral_polar_furbolg_ursa_warrior': 1,
#    u'npc_dota_neutral_satyr_hellcaller': 2,
#    u'npc_dota_neutral_satyr_soulstealer': 2,
#    u'npc_dota_neutral_satyr_trickster': 2},
#   u'killed_by': {u'npc_dota_hero_gyrocopter': 2,
#    u'npc_dota_hero_oracle': 1,
#    u'npc_dota_hero_templar_assassin': 2},
#   u'kills': 1,
#   u'kills_log': [{u'key': u'npc_dota_hero_batrider', u'time': 679}],
#   u'lane': 2,
#   u'lane_pos': {u'100': {u'114': 1, u'120': 2, u'138': 3, u'98': 1},
#    u'102': {u'100': 1, u'114': 1, u'116': 23, u'118': 13, u'138': 5},
#    u'104': {u'114': 1,
#     u'118': 1,
#     u'136': 1,
#     u'138': 3,
#     u'140': 4,
#     u'142': 1,
#     u'144': 1},
#    u'106': {u'100': 1, u'114': 1, u'142': 4, u'144': 1},
#    u'108': {u'100': 1, u'140': 3},
#    u'110': {u'100': 1, u'116': 1, u'130': 2, u'136': 1, u'138': 2},
#    u'112': {u'102': 1, u'116': 1, u'130': 1, u'132': 1, u'134': 2, u'140': 1},
#    u'114': {u'118': 1, u'122': 1, u'126': 2, u'128': 3, u'138': 1},
#    u'116': {u'104': 1, u'120': 1, u'124': 1, u'138': 1},
#    u'118': {u'104': 1, u'122': 1},
#    u'120': {u'104': 1, u'118': 1, u'120': 2, u'138': 1},
#    u'122': {u'116': 4,
#     u'118': 5,
#     u'120': 1,
#     u'122': 1,
#     u'136': 1,
#     u'138': 1,
#     u'140': 1},
#    u'124': {u'104': 1, u'116': 1, u'122': 1, u'124': 5, u'134': 1},
#    u'126': {u'106': 1,
#     u'122': 1,
#     u'124': 27,
#     u'126': 3,
#     u'130': 2,
#     u'132': 29},
#    u'128': {u'106': 1,
#     u'116': 1,
#     u'120': 2,
#     u'122': 1,
#     u'126': 2,
#     u'128': 5,
#     u'130': 1},
#    u'130': {u'114': 1, u'120': 1, u'126': 3, u'128': 2},
#    u'132': {u'108': 1, u'114': 1, u'128': 4},
#    u'134': {u'108': 1, u'112': 1, u'124': 1, u'126': 1},
#    u'136': {u'110': 1, u'124': 3, u'128': 2},
#    u'138': {u'108': 1, u'128': 1},
#    u'140': {u'108': 1, u'110': 1, u'124': 1, u'126': 2, u'128': 1},
#    u'142': {u'108': 1, u'110': 1, u'120': 1, u'124': 1, u'126': 2, u'128': 1},
#    u'144': {u'108': 1,
#     u'112': 1,
#     u'118': 1,
#     u'120': 1,
#     u'124': 1,
#     u'126': 1,
#     u'128': 1,
#     u'130': 2},
#    u'146': {u'114': 1, u'116': 2, u'118': 2, u'120': 2, u'122': 3},
#    u'148': {u'108': 1, u'112': 2, u'114': 2, u'116': 1, u'118': 1, u'120': 2},
#    u'150': {u'108': 1, u'110': 1, u'122': 3, u'124': 2, u'128': 9},
#    u'152': {u'108': 2},
#    u'156': {u'106': 1},
#    u'168': {u'82': 1, u'84': 1},
#    u'170': {u'80': 1, u'82': 5},
#    u'70': {u'156': 1, u'74': 28},
#    u'72': {u'156': 5, u'158': 1, u'74': 3, u'76': 6},
#    u'74': {u'102': 1,
#     u'104': 1,
#     u'108': 1,
#     u'110': 1,
#     u'114': 1,
#     u'118': 1,
#     u'138': 2,
#     u'140': 1,
#     u'142': 1,
#     u'154': 2,
#     u'76': 4,
#     u'78': 13,
#     u'80': 5,
#     u'82': 1,
#     u'84': 2,
#     u'86': 1,
#     u'88': 1,
#     u'90': 1,
#     u'92': 2,
#     u'96': 1,
#     u'98': 1},
#    u'76': {u'106': 2,
#     u'108': 3,
#     u'110': 1,
#     u'114': 1,
#     u'116': 1,
#     u'120': 1,
#     u'124': 1,
#     u'138': 4,
#     u'140': 5,
#     u'142': 4,
#     u'144': 6,
#     u'146': 6,
#     u'148': 4,
#     u'150': 7,
#     u'152': 10,
#     u'154': 2,
#     u'156': 1,
#     u'78': 2,
#     u'80': 1,
#     u'90': 1,
#     u'94': 1,
#     u'96': 1,
#     u'98': 1},
#    u'78': {u'100': 1,
#     u'104': 1,
#     u'106': 4,
#     u'108': 1,
#     u'110': 2,
#     u'112': 2,
#     u'114': 2,
#     u'118': 1,
#     u'120': 3,
#     u'122': 2,
#     u'124': 1,
#     u'126': 2,
#     u'128': 1,
#     u'132': 1,
#     u'134': 1,
#     u'136': 3,
#     u'138': 2,
#     u'140': 5,
#     u'142': 5,
#     u'144': 15,
#     u'146': 12,
#     u'148': 13,
#     u'150': 16,
#     u'152': 4,
#     u'154': 1,
#     u'156': 2,
#     u'158': 2,
#     u'80': 1},
#    u'80': {u'104': 10,
#     u'106': 3,
#     u'114': 1,
#     u'126': 1,
#     u'128': 1,
#     u'134': 1,
#     u'136': 1,
#     u'144': 4,
#     u'146': 9,
#     u'148': 14,
#     u'150': 6,
#     u'152': 9,
#     u'154': 5,
#     u'156': 3,
#     u'82': 1},
#    u'82': {u'128': 1,
#     u'130': 1,
#     u'132': 2,
#     u'134': 1,
#     u'140': 1,
#     u'142': 6,
#     u'144': 4,
#     u'146': 1,
#     u'154': 2,
#     u'84': 1},
#    u'84': {u'114': 1,
#     u'130': 2,
#     u'132': 2,
#     u'140': 6,
#     u'154': 1,
#     u'86': 1,
#     u'88': 1},
#    u'86': {u'112': 1, u'132': 1, u'138': 5, u'90': 1},
#    u'88': {u'130': 2, u'136': 5, u'92': 1},
#    u'90': {u'112': 1, u'130': 1, u'134': 1, u'136': 4, u'92': 1},
#    u'92': {u'112': 1, u'124': 1, u'126': 1, u'128': 2, u'136': 2, u'94': 1},
#    u'94': {u'112': 1, u'124': 1, u'134': 1, u'136': 2, u'96': 1},
#    u'96': {u'124': 1, u'134': 1, u'136': 4},
#    u'98': {u'114': 1, u'122': 2, u'136': 3, u'138': 5, u'98': 1}},
#   u'lane_role': 2,
#   u'last_hits': 70,
#   u'leaver_status': 0,
#   u'level': 11,
#   u'lh_t': [0,
#    1,
#    2,
#    3,
#    3,
#    4,
#    4,
#    8,
#    8,
#    13,
#    14,
#    17,
#    17,
#    17,
#    22,
#    32,
#    38,
#    39,
#    39,
#    42,
#    47,
#    56,
#    57,
#    61,
#    62,
#    62,
#    68,
#    68,
#    68,
#    68,
#    70,
#    70,
#    70,
#    70],
#   u'life_state': {u'0': 1858, u'1': 10, u'2': 156},
#   u'match_id': 2521743304,
#   u'max_hero_hit': {u'inflictor': u'earthshaker_fissure',
#    u'key': u'npc_dota_hero_gyrocopter',
#    u'max': True,
#    u'player_slot': 0,
#    u'slot': 0,
#    u'time': 1727,
#    u'type': u'max_hero_hit',
#    u'unit': u'npc_dota_hero_earthshaker',
#    u'value': 261},
#   u'multi_kills': {},
#   u'obs': {},
#   u'obs_left_log': [],
#   u'obs_log': [],
#   u'obs_placed': None,
#   u'observers_placed': None,
#   u'party_id': None,
#   u'party_size': None,
#   u'permanent_buffs': None,
#   u'pings': {u'0': 16},
#   u'player_slot': 0,
#   u'purchase': {u'arcane_boots': 1,
#    u'blink': 1,
#    u'boots': 1,
#    u'branches': 2,
#    u'circlet': 1,
#    u'clarity': 2,
#    u'energy_booster': 1,
#    u'force_staff': 1,
#    u'magic_stick': 1,
#    u'magic_wand': 1,
#    u'recipe_force_staff': 1,
#    u'ring_of_regen': 1,
#    u'smoke_of_deceit': 1,
#    u'staff_of_wizardry': 1,
#    u'tango': 1,
#    u'tpscroll': 7},
#   u'purchase_log': [{u'key': u'boots', u'time': -86},
#    {u'key': u'tango', u'time': -86},
#    {u'key': u'clarity', u'time': -85},
#    {u'key': u'clarity', u'time': -84},
#    {u'key': u'tpscroll', u'time': 233},
#    {u'key': u'arcane_boots', u'time': 303},
#    {u'key': u'energy_booster', u'time': 303},
#    {u'key': u'tpscroll', u'time': 346},
#    {u'key': u'tpscroll', u'time': 450},
#    {u'key': u'tpscroll', u'time': 476},
#    {u'key': u'tpscroll', u'time': 590},
#    {u'key': u'tpscroll', u'time': 787},
#    {u'key': u'tpscroll', u'time': 813},
#    {u'key': u'blink', u'time': 932},
#    {u'key': u'circlet', u'time': 1014},
#    {u'key': u'branches', u'time': 1014},
#    {u'key': u'branches', u'time': 1026},
#    {u'key': u'magic_wand', u'time': 1044},
#    {u'key': u'magic_stick', u'time': 1044},
#    {u'key': u'smoke_of_deceit', u'time': 1061},
#    {u'key': u'staff_of_wizardry', u'time': 1262},
#    {u'key': u'ring_of_regen', u'time': 1433},
#    {u'key': u'force_staff', u'time': 1572}],
#   u'roshans_killed': 0,
#   u'rune_pickups': None,
#   u'runes': {u'5': 2},
#   u'runes_log': [{u'key': 5, u'time': 427}, {u'key': 5, u'time': 1484}],
#   u'sen': {},
#   u'sen_left_log': [],
#   u'sen_log': [],
#   u'sen_placed': None,
#   u'stuns': 43.3916,
#   u'teamfight_participation': 0.727273,
#   u'times': [0,
#    60,
#    120,
#    180,
#    240,
#    300,
#    360,
#    420,
#    480,
#    540,
#    600,
#    660,
#    720,
#    780,
#    840,
#    900,
#    960,
#    1020,
#    1080,
#    1140,
#    1200,
#    1260,
#    1320,
#    1380,
#    1440,
#    1500,
#    1560,
#    1620,
#    1680,
#    1740,
#    1800,
#    1860,
#    1920,
#    1980],
#   u'tower_damage': 0,
#   u'towers_killed': 0,
#   u'xp_per_min': 225,
#   u'xp_reasons': {u'0': 267, u'1': 1389, u'2': 5409},
#   u'xp_t': [0,
#    180,
#    270,
#    382,
#    531,
#    867,
#    1002,
#    1315,
#    1585,
#    2167,
#    2435,
#    2660,
#    2980,
#    3017,
#    3377,
#    4026,
#    4175,
#    4209,
#    4635,
#    4857,
#    4994,
#    5825,
#    5944,
#    6169,
#    6400,
#    6618,
#    6958,
#    6958,
#    7006,
#    7006,
#    7034,
#    7056,
#    7056,
#    7056]}]

# %% [markdown]
# ###### mmr_estimates
# Not sure why the database lists MMR as an estimate.

# %%
mmr_request = '''
SELECT * FROM mmr_estimates LIMIT 1;
'''
explorer_request(mmr_request)
# Out:
# [{u'account_id': 327857781, u'estimate': 2324}]

# %% [markdown]
# ###### hero_ranking
# Unclear whether higher or lower is better for hero ranking. Also unclear how the score is calculated, though presumably it's based on a number of factors such as winrate, gpm, kills, deaths, tower damage. Does it only show heroes which have been played a certain number of times?

# %%
hero_ranking_request = '''
SELECT * FROM hero_ranking WHERE account_id = 178171791
'''
explorer_request(hero_ranking_request)
# Out:
# [{u'account_id': 178171791, u'hero_id': 2, u'score': 0.00297070883637009},
#  {u'account_id': 178171791, u'hero_id': 3, u'score': 0.0333496595784392},
#  {u'account_id': 178171791, u'hero_id': 7, u'score': 0.178081511642406},
#  {u'account_id': 178171791, u'hero_id': 9, u'score': 0.132611038905244},
#  {u'account_id': 178171791, u'hero_id': 14, u'score': 0.0376729461746511},
#  {u'account_id': 178171791, u'hero_id': 18, u'score': 0.0333496595784392},
#  {u'account_id': 178171791, u'hero_id': 19, u'score': 0.0600666011804639},
#  {u'account_id': 178171791, u'hero_id': 21, u'score': 0.0665537737648762},
#  {u'account_id': 178171791, u'hero_id': 26, u'score': 0.0333496595784392},
#  {u'account_id': 178171791, u'hero_id': 27, u'score': 0.120878180075593},
#  {u'account_id': 178171791, u'hero_id': 28, u'score': 0.00345908790462868},
#  {u'account_id': 178171791, u'hero_id': 29, u'score': 0.00246191057805359},
#  {u'account_id': 178171791, u'hero_id': 30, u'score': 0.0719351228098365},
#  {u'account_id': 178171791, u'hero_id': 31, u'score': 0.00907025181794659},
#  {u'account_id': 178171791, u'hero_id': 37, u'score': 0.00495661469129668},
#  {u'account_id': 178171791, u'hero_id': 39, u'score': 0.00404115618891721},
#  {u'account_id': 178171791, u'hero_id': 47, u'score': 0.00505965777687288},
#  {u'account_id': 178171791, u'hero_id': 51, u'score': 0.0333496595784392},
#  {u'account_id': 178171791, u'hero_id': 55, u'score': 0.0193208862836687},
#  {u'account_id': 178171791, u'hero_id': 56, u'score': 0.00274111717861611},
#  {u'account_id': 178171791, u'hero_id': 57, u'score': 0.00529149153475617},
#  {u'account_id': 178171791, u'hero_id': 59, u'score': 0.00437639349412688},
#  {u'account_id': 178171791, u'hero_id': 64, u'score': 0.00401632581327945},
#  {u'account_id': 178171791, u'hero_id': 67, u'score': 0.00551620188439453},
#  {u'account_id': 178171791, u'hero_id': 69, u'score': 0.00635131812333623},
#  {u'account_id': 178171791, u'hero_id': 70, u'score': 0.00456679037826331},
#  {u'account_id': 178171791, u'hero_id': 71, u'score': 0.00679107572404762},
#  {u'account_id': 178171791, u'hero_id': 83, u'score': 0.122693021189958},
#  {u'account_id': 178171791, u'hero_id': 88, u'score': 0.00489534306011599},
#  {u'account_id': 178171791, u'hero_id': 90, u'score': 0.0206510255351824},
#  {u'account_id': 178171791, u'hero_id': 95, u'score': 0.0100708860614028},
#  {u'account_id': 178171791, u'hero_id': 96, u'score': 0.0102715230140145},
#  {u'account_id': 178171791, u'hero_id': 97, u'score': 0.0179462843311137},
#  {u'account_id': 178171791, u'hero_id': 99, u'score': 0.00549987875388598},
#  {u'account_id': 178171791, u'hero_id': 101, u'score': 0.0116033462192678},
#  {u'account_id': 178171791, u'hero_id': 107, u'score': 0.0701089872195993},
#  {u'account_id': 178171791, u'hero_id': 110, u'score': 0.00942207715731618},
#  {u'account_id': 178171791, u'hero_id': 111, u'score': 0.0329571419576035},
#  {u'account_id': 178171791, u'hero_id': 112, u'score': 0.0295116638704108},
#  {u'account_id': 178171791, u'hero_id': 114, u'score': 0.0135498922355314}]

# %% [markdown]
# ###### heroes
# Hero information may be useful when we get to visualization. We could also allow the user to specify what roles they want the recommender to choose from or what attr, attack type they want.

# %%
hero_query = '''
SELECT * FROM heroes LIMIT 1
'''
explorer_request(hero_query)
# Out:
# [{u'attack_type': u'Melee',
#   u'id': 44,
#   u'legs': 2,
#   u'localized_name': u'Phantom Assassin',
#   u'name': u'npc_dota_hero_phantom_assassin',
#   u'primary_attr': u'agi',
#   u'roles': [u'Carry', u'Escape']}]

# %% [markdown]
# ###### team_match
# Not really sure how we could use team match information. It may be an easier way to tell which team a player is on for a given match.

# %%
team_match_query = '''
SELECT * FROM team_match LIMIT 1
'''
explorer_request(team_match_query)
# Out:
# [{u'match_id': 672230339, u'radiant': True, u'team_id': 260085}]

# %% [markdown]
# If we want to get hero pickrate and hero winrate by player and use those to calculate our own metrics we would have to query

# %% [markdown]
# # Writing to our database

# %%
cm_rows = explorer_request(cm_query)
cm_dict = defaultdict(list)
for key in cm_rows[0]:
    for row in cm_rows:
        cm_dict[key].append(row[key])
df = pd.DataFrame(data=cm_dict)

# %%
df.head()
# Out:
#    duration    match_id  match_seq_num  \
# 0      1969  3180507665     2778110720
# 1      1356  3180707501     2778275515
# 2      1705  3180807310     2778377937
# 3      2338  3180828452     2778416570
# 4      2570  3180953074     2778549215
#
#                                           picks_bans  radiant_win
# 0  [{u'team': 1, u'hero_id': 114, u'order': 0, u'...         True
# 1  [{u'team': 1, u'hero_id': 57, u'order': 0, u'i...         True
# 2  [{u'team': 1, u'hero_id': 32, u'order': 0, u'i...        False
# 3  [{u'team': 1, u'hero_id': 25, u'order': 0, u'i...        False
# 4  [{u'team': 0, u'hero_id': 99, u'order': 0, u'i...         True

# %%
with open(os.path.expanduser('~/.pgpass')) as f:
    for line in f:
        host, port, db, user, password = [x.strip() for x in line.split(':')]
        if db == 'dota-draft-test':
            break
conn, meta = connect(user=user, password=password, db=db, host=host, port=port)

# %% [markdown]
# # Unnesting JSON and Joining with Player data

# %%
query = '''
SELECT match_id, unnest(picks_bans) FROM matches LIMIT 21
'''
explorer_request(query)
# Out:
# [{u'match_id': 728669374,
#   u'unnest': {u'hero_id': 89, u'is_pick': False, u'order': 0, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 77, u'is_pick': False, u'order': 1, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 69, u'is_pick': False, u'order': 2, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 58, u'is_pick': False, u'order': 3, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 65, u'is_pick': True, u'order': 4, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 106, u'is_pick': True, u'order': 5, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 9, u'is_pick': True, u'order': 6, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 10, u'is_pick': True, u'order': 7, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 103, u'is_pick': False, u'order': 8, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 78, u'is_pick': False, u'order': 9, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 74, u'is_pick': False, u'order': 10, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 29, u'is_pick': False, u'order': 11, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 53, u'is_pick': True, u'order': 12, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 87, u'is_pick': True, u'order': 13, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 68, u'is_pick': True, u'order': 14, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 27, u'is_pick': True, u'order': 15, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 47, u'is_pick': False, u'order': 16, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 86, u'is_pick': False, u'order': 17, u'team': 1}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 41, u'is_pick': True, u'order': 18, u'team': 0}},
#  {u'match_id': 728669374,
#   u'unnest': {u'hero_id': 67, u'is_pick': True, u'order': 19, u'team': 1}},
#  {u'match_id': 1983562843,
#   u'unnest': {u'hero_id': 39, u'is_pick': False, u'order': 0, u'team': 0}}]

# %% [markdown]
# # Testing Functions
# Check if your DB is being updated

# %%
build_matches(conn)
# %timeit match_seq_range = append_matches(conn, 20, start, end)
# Out:
# 1 loop, best of 3: 232 ms per loop

# %%
build_player_matches(conn)
# %timeit append_player_matches(conn, start, end, *match_seq_range)
# player_matches table should have 40 rows now
# Out:
# 1 loop, best of 3: 277 ms per loop

# %%
build_heroes(conn)

# %%
build_hero_ranking(conn)
# %timeit append_hero_ranking(conn, start, end, *match_seq_range)
# Out:
# 1 loop, best of 3: 702 ms per loop

# %%
build_mmr_estimates(conn)
# %timeit append_mmr_estimates(conn, start, end, *match_seq_range)
# Out:
# 1 loop, best of 3: 344 ms per loop

# %%
match_seq_range
# Out:
# (2780546657, 2782858339)

# %%
url = 'https://api.opendota.com/api/explorer?sql='
query = '''
SELECT COUNT(*) FROM matches WHERE
start_time BETWEEN {start} AND {end}
AND game_mode = 2
'''.format(start=start, end=end)
json.loads(requests.get(url + urllib.quote(query)).content)['rows']
# Out:
# [{u'count': 7105}]

# %% [markdown]
# 20 matches with all player data takes ~ 3 seconds. Time will probably decrease the more queries it runs, as it populates the player database

# %%
query = '''
SELECT picks_bans FROM matches WHERE game_mode = 2 LIMIT 10;
'''
explorer_request(query)
# Out:
# [{u'picks_bans': [{u'hero_id': 89, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 77, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 69, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 58, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 65, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 106, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 9, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 103, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 78, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 29, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 53, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 87, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 68, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 27, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 47, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 86, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 41, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 67, u'is_pick': True, u'order': 19, u'team': 1}]},
#  {u'picks_bans': [{u'hero_id': 39, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 69, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 85, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 3, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 11, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 50, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 100, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 112, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 47, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 55, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 59, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 7, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 25, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 62, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 92, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 72, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 51, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 106, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 73, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 71, u'is_pick': True, u'order': 19, u'team': 0}]},
#  {u'picks_bans': [{u'hero_id': 73, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 91, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 28, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 69, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 11, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 112, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 100, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 50, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 85, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 55, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 61, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 18, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 39, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 31, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 65, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 19, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 60, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 68, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 44, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 15, u'is_pick': True, u'order': 19, u'team': 0}]},
#  {u'picks_bans': [{u'hero_id': 11, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 65, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 50, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 69, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 60, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 28, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 3, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 85, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 68, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 73, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 72, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 12, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 25, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 27, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 19, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 47, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 77, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 106, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 112, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 19, u'team': 1}]},
#  {u'picks_bans': [{u'hero_id': 73, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 29, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 41, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 9, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 93, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 57, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 18, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 97, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 87, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 26, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 7, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 86, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 20, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 34, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 6, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 28, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 95, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 61, u'is_pick': True, u'order': 19, u'team': 1}]},
#  {u'picks_bans': [{u'hero_id': 111,
#     u'is_pick': False,
#     u'order': 0,
#     u'team': 1},
#    {u'hero_id': 98, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 6, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 65, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 103, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 2, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 50, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 9, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 79, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 87, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 16, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 93, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 41, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 26, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 74, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 10, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 55, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 68, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 29, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 101, u'is_pick': True, u'order': 19, u'team': 0}]},
#  {u'picks_bans': [{u'hero_id': 83, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 65, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 77, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 19, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 91, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 90, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 9, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 10, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 55, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 78, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 79, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 88, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 42, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 13, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 46, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 58, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 51, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 2, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 96, u'is_pick': True, u'order': 19, u'team': 0}]},
#  {u'picks_bans': [{u'hero_id': 79, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 78, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 69, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 9, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 106, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 87, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 3, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 27, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 41, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 99, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 4, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 93, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 77, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 2, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 60, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 90, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 83, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 30, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 21, u'is_pick': True, u'order': 19, u'team': 0}]},
#  {u'picks_bans': [{u'hero_id': 83, u'is_pick': False, u'order': 0, u'team': 1},
#    {u'hero_id': 55, u'is_pick': False, u'order': 1, u'team': 0},
#    {u'hero_id': 91, u'is_pick': False, u'order': 2, u'team': 1},
#    {u'hero_id': 89, u'is_pick': False, u'order': 3, u'team': 0},
#    {u'hero_id': 65, u'is_pick': True, u'order': 4, u'team': 1},
#    {u'hero_id': 76, u'is_pick': True, u'order': 5, u'team': 0},
#    {u'hero_id': 92, u'is_pick': True, u'order': 6, u'team': 0},
#    {u'hero_id': 54, u'is_pick': True, u'order': 7, u'team': 1},
#    {u'hero_id': 62, u'is_pick': False, u'order': 8, u'team': 1},
#    {u'hero_id': 66, u'is_pick': False, u'order': 9, u'team': 0},
#    {u'hero_id': 15, u'is_pick': False, u'order': 10, u'team': 1},
#    {u'hero_id': 58, u'is_pick': False, u'order': 11, u'team': 0},
#    {u'hero_id': 88, u'is_pick': True, u'order': 12, u'team': 0},
#    {u'hero_id': 51, u'is_pick': True, u'order': 13, u'team': 1},
#    {u'hero_id': 63, u'is_pick': True, u'order': 14, u'team': 0},
#    {u'hero_id': 86, u'is_pick': True, u'order': 15, u'team': 1},
#    {u'hero_id': 90, u'is_pick': False, u'order': 16, u'team': 0},
#    {u'hero_id': 98, u'is_pick': False, u'order': 17, u'team': 1},
#    {u'hero_id': 69, u'is_pick': True, u'order': 18, u'team': 0},
#    {u'hero_id': 33, u'is_pick': True, u'order': 19, u'team': 1}]},
#  {u'picks_bans': [{u'hero_id': 77, u'is_pick': False, u'order': 0, u'team': 0},
#    {u'hero_id': 69, u'is_pick': False, u'order': 1, u'team': 1},
#    {u'hero_id': 65, u'is_pick': False, u'order': 2, u'team': 0},
#    {u'hero_id': 74, u'is_pick': False, u'order': 3, u'team': 1},
#    {u'hero_id': 103, u'is_pick': True, u'order': 4, u'team': 0},
#    {u'hero_id': 16, u'is_pick': True, u'order': 5, u'team': 1},
#    {u'hero_id': 27, u'is_pick': True, u'order': 6, u'team': 1},
#    {u'hero_id': 9, u'is_pick': True, u'order': 7, u'team': 0},
#    {u'hero_id': 43, u'is_pick': False, u'order': 8, u'team': 0},
#    {u'hero_id': 79, u'is_pick': False, u'order': 9, u'team': 1},
#    {u'hero_id': 47, u'is_pick': False, u'order': 10, u'team': 0},
#    {u'hero_id': 41, u'is_pick': False, u'order': 11, u'team': 1},
#    {u'hero_id': 78, u'is_pick': True, u'order': 12, u'team': 1},
#    {u'hero_id': 76, u'is_pick': True, u'order': 13, u'team': 0},
#    {u'hero_id': 29, u'is_pick': True, u'order': 14, u'team': 1},
#    {u'hero_id': 10, u'is_pick': True, u'order': 15, u'team': 0},
#    {u'hero_id': 86, u'is_pick': False, u'order': 16, u'team': 1},
#    {u'hero_id': 1, u'is_pick': False, u'order': 17, u'team': 0},
#    {u'hero_id': 93, u'is_pick': True, u'order': 18, u'team': 1},
#    {u'hero_id': 64, u'is_pick': True, u'order': 19, u'team': 0}]}]

# %%
s = map(lambda x: x['picks_bans'], explorer_request(query))

# %%
df = pd.DataFrame({'picks_bans': s})

# %%
df.head()
# Out:
#                                           picks_bans
# 0  [{u'team': 1, u'hero_id': 89, u'order': 0, u'i...
# 1  [{u'team': 0, u'hero_id': 39, u'order': 0, u'i...
# 2  [{u'team': 0, u'hero_id': 73, u'order': 0, u'i...
# 3  [{u'team': 1, u'hero_id': 11, u'order': 0, u'i...
# 4  [{u'team': 0, u'hero_id': 73, u'order': 0, u'i...

# %%
df.to_sql('picks_bans', conn, if_exists='replace', dtype={'picks_bans' : sqlalchemy.types.JSON})

# %%
query = '\n    SELECT match_id, duration,\n    picks_bans, radiant_win,\n    match_seq_num\n    FROM matches\n    WHERE start_time BETWEEN 1351237677 AND 1506284352\n    AND match_seq_num > 0\n    AND game_mode = 2\n    ORDER BY match_seq_num ASC\n    LIMIT 20;\n    '
explorer_request(query)
# Out:
# [{u'duration': 2975,
#   u'match_id': 53510908,
#   u'match_seq_num': 51269400,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 2460,
#   u'match_id': 53534174,
#   u'match_seq_num': 51292409,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1907,
#   u'match_id': 53609860,
#   u'match_seq_num': 51357335,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 3620,
#   u'match_id': 53641581,
#   u'match_seq_num': 51399649,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1548,
#   u'match_id': 53723251,
#   u'match_seq_num': 51459655,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1840,
#   u'match_id': 53733166,
#   u'match_seq_num': 51469957,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1094,
#   u'match_id': 53745978,
#   u'match_seq_num': 51475768,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1780,
#   u'match_id': 53776454,
#   u'match_seq_num': 51508352,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1999,
#   u'match_id': 53780877,
#   u'match_seq_num': 51512797,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1997,
#   u'match_id': 53800114,
#   u'match_seq_num': 51530959,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 2315,
#   u'match_id': 53797580,
#   u'match_seq_num': 51531938,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1352,
#   u'match_id': 54217526,
#   u'match_seq_num': 51914550,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1502,
#   u'match_id': 54240786,
#   u'match_seq_num': 51937615,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1168,
#   u'match_id': 54597908,
#   u'match_seq_num': 52269670,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1964,
#   u'match_id': 54621582,
#   u'match_seq_num': 52295306,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 2118,
#   u'match_id': 54737247,
#   u'match_seq_num': 52404555,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1612,
#   u'match_id': 54756734,
#   u'match_seq_num': 52418707,
#   u'picks_bans': None,
#   u'radiant_win': False},
#  {u'duration': 1091,
#   u'match_id': 54763343,
#   u'match_seq_num': 52421621,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 1487,
#   u'match_id': 54775378,
#   u'match_seq_num': 52434087,
#   u'picks_bans': None,
#   u'radiant_win': True},
#  {u'duration': 3906,
#   u'match_id': 54815312,
#   u'match_seq_num': 52485612,
#   u'picks_bans': None,
#   u'radiant_win': True}]

# %%
query = 'SELECT COUNT(*) FROM matches WHERE game_mode = 2 and picks_bans IS NOT NULL'
explorer_request(query)
# Out:
# [{u'count': 46347}]

# %%
query = 'SELECT COUNT(*) FROM matches WHERE game_mode = 2 AND picks_bans IS NULL'
explorer_request(query)
# Out:
# [{u'count': 855}]

# %%
query = 'SELECT start_time FROM matches LIMIT 5'
explorer_request(query)
# Out:
# [{u'start_time': 1338225112},
#  {u'start_time': 1338229643},
#  {u'start_time': 1338234128},
#  {u'start_time': 1338314072},
#  {u'start_time': 1338405104}]
